# %%
# Bottom 
import pandas as pd
from scipy.interpolate import griddata

fr = pd.read_csv("EXT.csv")
x = fr['Y1']
y = fr['Z1']
v = fr['V1']

y1s = [0.8,1.732,2.598,3.464,4.33,5.196,7.106,7.856] + [7.856]*18 + [0.8,1.732,2.598,3.464,4.33,5.196,7.106,7.856]
z1s = [0]*8 + [0.0, 0.7, 1.4, 2.1, 2.8, 3.5, 4.2, 4.9, 5.6, 6.3, 7.0, 7.7, 8.4, 9.1, 9.8, 10.5, 11.2, 11.9] + [11.9]*8

print(len(y1s))
print(len(z1s))
# # y1s = [0.75,
# # 0.75+0.75,
# # 0.75+0.75+0.75,
# # 0.75+0.75+0.75+0.75,
# # 0.75+0.75+0.75+0.75+0.75,
# # 0.75+0.75+0.75+0.75+0.75+0.75,
# # 0.75+0.75+0.75+0.75+0.75+0.75+0.75,
# # 0.75+0.75+0.75+0.75+0.75+0.75+0.75+0.75
# # ]
# z1s = [0]*8

v1 = [0]*34
for i, y1 in enumerate(y1s):
     z1 = z1s[i]
     v1[i] = griddata((x, y), v, (y1, z1), method='cubic')

df = pd.DataFrame(v1)

df.to_csv("result_ext.csv")

df
# Out:
# 34
# 34
#             0
# 0  -20.200000
# 1  -14.700000
# 2   -9.500000
# 3   -4.400000
# 4    0.800000
# 5    6.000000
# 6   15.300000
# 7   18.400000
# 8   18.400000
# 9   22.300000
# 10  25.700000
# 11  28.600000
# 12  30.700000
# 13  32.500000
# 14  33.800000
# 15  34.600000
# 16  35.000000
# 17  34.900000
# 18  34.400000
# 19  33.400000
# 20  32.000000
# 21  30.100000
# 22  27.700000
# 23  25.000000
# 24  17.100000
# 25  14.400000
# 26 -15.800000
# 27 -11.274233
# 28  -7.610217
# 29  -4.415632
# 30  -1.663591
# 31   0.835943
# 32  10.100000
# 33  14.400000

# %%
# Longi'l Bulkhead
import pandas as pd
from scipy.interpolate import griddata

fr = pd.read_csv("LBD.csv")
x = fr['Y1']
y = fr['Z1']
v = fr['V1']

y1s = [0.8]*18

z1s = [0.0,
0.7,
1.4,
2.1,
2.8,
3.5,
4.2,
4.9,
5.6,
6.3,
7.0,
7.7,
8.4,
9.1,
9.8,
10.5,
11.2,
11.9
]

v1 = [0]*18
for i, y1 in enumerate(y1s):
     z1 = z1s[i]
     v1[i] = griddata((x, y), v, (y1, z1), method='cubic')

df = pd.DataFrame(v1)

df.to_csv("result_lbhd.csv")

df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[34], line 5
#       2 import pandas as pd
#       3 from scipy.interpolate import griddata
# ----> 5 fr = pd.read_csv("LBHD.csv")
#       6 x = fr['Y1']
#       7 y = fr['Z1']
#
# ...

# %%
# Deck
import pandas as pd
from scipy.interpolate import griddata

fr0 = pd.read_csv("fr0.csv")
x = fr0['Y1']
y = fr0['Z1']
v = fr0['V1']


y1s = [0.8,
1.8,
2.6,
3.4,
4.2,
5.0,
7.106,
7.856
]

# y1s = [0.75,
# 0.75+0.75,
# 0.75+0.75+0.75,
# 0.75+0.75+0.75+0.75,
# 0.75+0.75+0.75+0.75+0.75,
# 0.75+0.75+0.75+0.75+0.75+0.75,
# 0.75+0.75+0.75+0.75+0.75+0.75+0.75,
# 0.75+0.75+0.75+0.75+0.75+0.75+0.75+0.75
# ]

z1s = [11.9]*8
v1 = [0]*8

for i, y1 in enumerate(y1s):
    z1 = z1s[i]
    v1[i] = griddata((x, y), v, (y1, z1), method='cubic')
#    interp_cubic.append(v1)

df = pd.DataFrame(v1)
df.to_csv("fr0_dk_v1.csv")

df
# Out:
#            0
# 0 -15.800000
# 1 -10.223192
# 2  -6.417294
# 3  -3.735192
# 4  -2.525387
# 5  -0.849270
# 6  10.100000
# 7  14.400000
